# %%
import pandas as pd

# %%
df = pd.read_csv("D:/Datasets/ESAM/BKP_ALUMNOS_20260803_ESAM.csv")
df.head(5)
# Out:
#   Cod_Unico Cod_Academico Id_Esam Cod_Contable  \
# 0       576    R-EM20-003   D-129     DIQ-8018
# 1       576    R-EM20-003   D-129     DIQ-8018
# 2       576    R-EM20-003   D-129     DIQ-8018
# 3       576    R-EM20-003   D-129     DIQ-8018
# 4       576    R-EM20-003   D-129     DIQ-8018
#
#                                             Programa  Gestion       Tipo  \
# 0  Diplomado En Instrumentación Quirúrgica V-1 G-...     2019  Diplomado
# 1  Diplomado En Instrumentación Quirúrgica V-1 G-...     2019  Diplomado
# 2  Diplomado En Instrumentación Quirúrgica V-1 G-...     2019  Diplomado
# 3  Diplomado En Instrumentación Quirúrgica V-1 G-...     2019  Diplomado
# 4  Diplomado En Instrumentación Quirúrgica V-1 G-...     2019  Diplomado
#
#             Sede Convenio  Id_Inscripcion  ... Id_Detalle_Pago  \
# 0  Esam Tarija 2    UNSXX               1  ...               -
# 1  Esam Tarija 2    UNSXX               2  ...               -
# ...

# %% [markdown]
# 92587
# 91939
# 90737
# 91542
# 90294
# 93796
# 97672
# 93809

# %%
consulta1 = df[df["Id_Inscripcion"].isin([237090])][["Id_Inscripcion","Programa","Sede","ALUMNO","CI","Estado_Administrativo","Estado_Esam","Estado_Academico","estado_cartera","monto_pagado_fase_formativa","monto_pagado_certificacion"]]
consulta1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 consulta1 = df[df["Id_Inscripcion"].isin([237090])][["Id_Inscripcion","Programa","Sede","ALUMNO","CI","Estado_Administrativo","Estado_Esam","Estado_Academico","estado_cartera","monto_pagado_fase_formativa","monto_pagado_certificacion"]]
#       2 consulta1
#
# File c:\Users\HUAWEI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
consulta2 = df[df["Estado_Administrativo"].isin(["Prospecto"])][["Id_inscripcion","Programa","Sede","ALUMNO","CI","Estado_Administrativo", "Estado_Esam","Estado_Academico","estado_cartera","monto_pagado_fase_formativa","monto_pagado_certificacion"]]
consulta2
# Out:
#        Id_inscripcion                                           Programa  \
# 92                125  Maestría En Derecho Procesal Penal V-2 G-2 S-2...
# 94                127  Maestría En Derecho Procesal Penal V-2 G-2 S-2...
# 101               134  Maestría En Derecho Procesal Penal V-2 G-2 S-2...
# 104               137  Maestría En Derecho Procesal Penal V-2 G-2 S-2...
# 105               138  Maestría En Derecho Procesal Penal V-2 G-2 S-2...
# ...               ...                                                ...
# 95174          222458  MAESTRÍA EN EDUCACIÓN SUPERIOR POR COMPETENCIA...
# 95190          222509  MAESTRÍA EN SALUD PÚBLICA CON MENCIÓN EN EPIDE...
# 95214          222566  Maestría En Derecho Civil Y Procesal Civil (V2...
# 95215          222568  MAESTRÍA EN INGENIERÍA VIAL CON MENCIÓN EN CAR...
# 95216          222569  MAESTRÍA EN SALUD PÚBLICA CON MENCIÓN EN EPIDE...
#
#                   Sede                          ALUMNO       CI  \
# ...
